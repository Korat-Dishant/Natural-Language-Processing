# %%
  import nltk
  nltk.download('punkt')
  nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = "HII, I am dishant korat. I am pursuing my batchelors from L.D.R.P-itr in the field of computing"
tokens = nltk.word_tokenize(text)
print(tokens)
tag = nltk.pos_tag(tokens)
print(tag)
# Out:
# ['HII', ',', 'I', 'am', 'dishant', 'korat', '.', 'I', 'am', 'pursuing', 'my', 'batchelors', 'from', 'L.D.R.P-itr', 'in', 'the', 'field', 'of', 'computing']
# [('HII', 'NNP'), (',', ','), ('I', 'PRP'), ('am', 'VBP'), ('dishant', 'JJ'), ('korat', 'NN'), ('.', '.'), ('I', 'PRP'), ('am', 'VBP'), ('pursuing', 'VBG'), ('my', 'PRP$'), ('batchelors', 'NNS'), ('from', 'IN'), ('L.D.R.P-itr', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('field', 'NN'), ('of', 'IN'), ('computing', 'VBG')]
